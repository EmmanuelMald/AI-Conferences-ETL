# %% [markdown]
# # AI-Events Extractor
#
# This notebook tests the code to extract AI-related events using web-scrapping from different sources

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd

# %%
# Step 1: Fetch the page
url = "https://www.unite.ai/conferences/"
headers = {"User-Agent": "Mozilla/5.0"}
response = requests.get(url, headers=headers)
soup = BeautifulSoup(response.content, "html.parser")

# Paso 2: Buscar el tbody directamente
tbody = soup.find("tbody", class_="row-striping")
rows = tbody.find_all("tr")

# Paso 3: Extraer los datos
conferences = []
for row in rows:
    cols = row.find_all("td")
    if len(cols) >= 3:
        dates = cols[0].get_text(strip=True)
        title_tag = cols[1].find("a")
        title = title_tag.get_text(strip=True) if title_tag else cols[1].get_text(strip=True)
        link = title_tag["href"] if title_tag and "href" in title_tag.attrs else None
        location = cols[2].get_text(strip=True)

        conferences.append({
            "Title": title,
            "Dates": dates,
            "Location": location,
            "Link": link
        })

# Paso 4: Mostrar resultados
for conf in conferences:
    print(conf)
# Out:
# {'Title': 'GAI World 2025', 'Dates': 'September 29 to 30, 2025', 'Location': 'Boston, MA', 'Link': 'https://www.gaiworld.com/'}
# {'Title': '7th Annual Machine Learning in Quantitative Finance', 'Dates': 'September 29 to October 1, 2025', 'Location': 'New York, NY', 'Link': 'https://bit.ly/4mzG8SL'}
# {'Title': '2nd Edition AI and ML Model Development, Risk and Governance', 'Dates': 'September 29 to October 1, 2025', 'Location': 'New York, NY', 'Link': 'https://www.marcusevans.com/conferences/aifinance?utm_source=media+partner&utm_medium=uai+event+listing&utm_campaign=ukcm-co-00019+-+uai&utm_id=ukcm-co-00019'}
# {'Title': '3rd Annual Development, Implementation and Management of ML Models', 'Dates': 'September 29 to October 1, 2025', 'Location': 'New York, NY', 'Link': 'https://bit.ly/3SmSfVt'}
# {'Title': 'MLcon New York', 'Dates': 'September 30 to October 1, 2025', 'Location': 'New York, NY', 'Link': 'https://mlconference.ai/new-york/'}
# {'Title': 'SDV & AI in Automotive USA 2025', 'Dates': 'September 30 to October 2, 2025', 'Location': 'Ann Arbor, Mi', 'Link': 'https://www.automotive-iq.com/events-software-defined-vehicles-ai-usa/downloads/ai-in-automotive-usa-2025-agenda?-ty-b'}
# {'Title': 'AI in Health summit', 'Dates': 'October 1, 2025', 'Location': 'London, UK', 'Link': 'http://econimpact.co/UF'}
# {'Title': '1682: The Business of Innovation Conference', 'Dates': 'October 8, 2025', 'Location': 'Philadelphia, PA', 'Link': 'https://www.1682conference.com/'}
# {'Title': 'World Summit AI', 'Dates': 'October 8 to 9, 2025', 'Location': 'Amsterdam, NL', 'Link': 'https://worldsummit.ai/'}
# {'Title': 'CDAO Fall', 'Dates': 'October 14 to 15, 2025', 'Location': 'Boston, MA', 'Link': 'https://cdao-fall.coriniumintelligence.com/'}
# {'Title': 'DSC DACH 25', 'Dates': 'October 14 to 16, 2025', 'Location': 'Vienna, Austria', 'Link': 'https://dscdach.com/'}
# {'Title': 'Banking Transformation Summit', 'Dates': 'October 15, 2025', 'Location': 'Singapore, SG', 'Link': 'https://asia.bankingtransformationsummit.com/'}
# {'Title': 'North American Intelligent Cockpit and Smart Driving Summit 2025', 'Dates': 'October 15 to 16, 2025', 'Location': 'Detroit, MI', 'Link': 'https://www.ecv-events.com/NAICSDS2025'}
# {'Title': 'AI for the rest of us', 'Dates': 'October 15 to 16, 2025', 'Location': 'London, UK', 'Link': 'https://aifortherestofus.live/london-2025'}
# {'Title': 'Gen AI & HyperAutomation in Finance Summit', 'Dates': 'October 16, 2025', 'Location': 'Chicago, IL', 'Link': 'https://kinfos.events/haf/'}
# {'Title': 'dAGI Summit 2025, SF (Open Source AI Week)', 'Dates': 'October 24, 2025', 'Location': 'San Francisco, CA', 'Link': 'https://dagihouse.com/?utm_source=media_uniteai&utm_medium=social&utm_campaign=promocode <br />\n'}
# {'Title': 'Agentic AI Summit,', 'Dates': 'October 27 to 28, 2025', 'Location': 'Amsterdam, NL', 'Link': 'https://www.aidataanalytics.network/events-agentic-ai-summit/landing/get-your-copy-of-the-2025-agenda-12/?utm_source=Banner&utm_medium=Media%20Partner&utm_campaign=51391.001-UniteAI-Event-Listing&utm_term=&utm_content=&disc=&extTreatId=7621898'}
# {'Title': 'ODSC AI West 2025', 'Dates': 'October 28 to 30, 2025', 'Location': 'San Francisco, CA', 'Link': 'https://odsc.ai/'}
# {'Title': 'The AI Revolution Summit', 'Dates': 'October 30, 2025', 'Location': 'Manila, Phillipines', 'Link': 'https://air.traiconevents.com/philippines/'}
# {'Title': 'AI Expo Europe', 'Dates': 'November 2 to 3, 2025', 'Location': 'Bucharest, Romania', 'Link': 'https://www.aiexpoeurope.com/'}
# {'Title': 'Post‑Industrial Summit 2025: Autonomous Organizations', 'Dates': 'November 5 to 6, 2025', 'Location': 'Menlo Park, CA', 'Link': 'https://post-industrial.institute/summit-2025/'}
# {'Title': 'Future of AI', 'Dates': 'November 5 to 6, 2025', 'Location': 'London, UK', 'Link': 'https://ai.live.ft.com/?promo=UNITEAI&utm_source=partner-emp&utm_medium=email&utm_campaign=global_partner_traffic_prospecting_bau_2025_future_of_ai_summit_london&utm_term=email-1&utm_content=uniteai'}
# {'Title': 'Conversational AI & Customer Experience Summit', 'Dates': 'November 5 to 6, 2025', 'Location': 'Munich, Germany', 'Link': 'https://conversationaltechsummit.com/'}
# {'Title': '9th Edition Model Risk Management for Financial Institutions', 'Dates': 'November 5 to 7, 2025', 'Location': 'London, UK', 'Link': 'https://www.marcusevans.com/conferences/modelriskmanagement'}
# {'Title': 'AI INFRA SUMMIT', 'Dates': 'November 7, 2025', 'Location': 'San Francisco, CA', 'Link': 'https://lu.ma/aiinfra_4?coupon=AT2LIM35'}
# {'Title': 'AI Summit Seoul & Expo (AIS)', 'Dates': 'November 10 to 11, 2025', 'Location': 'Seoul, Korea', 'Link': 'https://www.aisummitseoul.com/program2025'}
# {'Title': 'AI Regulation Summit', 'Dates': 'November 11, 2025', 'Location': 'London, UK', 'Link': 'https://www.cityandfinancialglobal.com/the-3rd-annual-ai-regulation-summit/begin?code=GA3UI'}
# {'Title': 'Generative AI Week', 'Dates': 'November 11 to 12, 2025', 'Location': 'Austin, TX', 'Link': 'https://www.aidataanalytics.network/events-generative-ai-week/?utm_source=47860.003_MP_UniteAI&utm_medium=Media%20Partner&utm_campaign=47860.003_MediaPartner_UniteAI&utm_term=&utm_content=&disc=&extTreatId=7618095'}
# {'Title': 'AI Policy summit', 'Dates': 'November 12, 2025', 'Location': 'London, UK', 'Link': 'https://www.cityandfinancialglobal.com/the-uk-national-ai-policy-summit-2025/home'}
# {'Title': 'CDAO Fed Ready Q4', 'Dates': 'November 12, 2025', 'Location': 'Washington D.C.', 'Link': 'https://cdao-federal.coriniumintelligence.com/q4'}
# {'Title': 'Artificial Intelligence and Machine Learning Conference 2025', 'Dates': 'November 13 to 14, 2025', 'Location': 'Singapore, SG', 'Link': 'https://pubscholars.org/ai-and-machine-learning-conference/'}
# {'Title': 'AI for Marketers Summit', 'Dates': 'November 13 to 14, 2025', 'Location': 'Digital', 'Link': 'https://bit.ly/3DUK2UT'}
# {'Title': 'Banking Transformation Summit', 'Dates': 'November 17 to 18, 2025', 'Location': 'Charlotte, NC', 'Link': 'https://na.bankingtransformationsummit.com/'}
# {'Title': 'DSC Europe 25', 'Dates': 'November 17 to 21, 2025', 'Location': 'Belgrade, Serbia', 'Link': 'https://datasciconference.com/'}
# {'Title': 'EBINTEC Banking Innovation Conference and Exhibition', 'Dates': 'November 18, 2025', 'Location': 'Dubai, UAE', 'Link': 'https://www.ebintec.com'}
# {'Title': 'AI in Healthcare Summit', 'Dates': 'November 18 to 19, 2025', 'Location': 'Boston, MA', 'Link': 'https://boston-ai-healthcare.re-work.co/'}
# {'Title': 'Generative AI for Marketing Summit', 'Dates': 'November 24 to 26, 2025', 'Location': 'London, UK', 'Link': 'https://www.aidataanalytics.network/events-generative-ai-for-marketing/?utm_source=Media%20Partner1&utm_medium=Media%20Partner&utm_campaign=48322.002-MP-UniteAI-Listing&utm_term=&utm_content=&disc=&extTreatId=7616343'}
# {'Title': 'MLcon Berlin', 'Dates': 'November 24 to 28, 2025', 'Location': 'Berlin, Germany', 'Link': 'https://mlconference.ai/berlin/'}
# {'Title': 'AI World Forum Congress 2025', 'Dates': 'November 26 to 27, 2025', 'Location': 'London, UK', 'Link': 'https://aiconference.london/'}
# {'Title': 'Defence Transformation', 'Dates': 'December 3 to 4, 2025', 'Location': 'London, UK', 'Link': 'https://www.defenceiq.com/events-defencetransformation/?utm_source=UniteAI&utm_medium=Social&utm_campaign=28847.009_UniteAI_Media_Partner&utm_term=&utm_content=&disc=&extTreatId=7621840'}
# {'Title': '27th Edition Model Risk Management for Financial Institutions', 'Dates': 'December 3 to 5, 2025', 'Location': 'New York, NY', 'Link': 'https://www.marcusevans.com/conferences/model-risk?utm_source=media+partner&utm_medium=uai+event+listing&utm_campaign=gfmi-co-00024+-+uai&utm_id=gfmi-co-00024'}
# {'Title': '3rd Annual AGENTIC AI 2025 | Generative AI Europe', 'Dates': 'December 3 to 5, 2025', 'Location': 'Barcelona, Spain', 'Link': 'https://www.aidataanalytics.network/events-generative-ai-europe/agenda-mc/?utm_source=Diary%20Listing&utm_medium=Media%20Partner&utm_campaign=48074.003%20-%20UNITE.AI%20Event%20Listing&utm_term=&utm_content=&disc=&extTreatId=7624219<br />\n'}
# {'Title': 'World Summit AI', 'Dates': 'December 9 to 10, 2025', 'Location': 'Doha, Qatar', 'Link': 'https://qatar.worldsummit.ai'}
# {'Title': 'AI Summit New York 2025', 'Dates': 'December 10 to 11, 2025', 'Location': 'New York, NY', 'Link': 'https://newyork.theaisummit.com/?_mc=cl_aisny_x_aisny_le_x_x_x_x_x_na_uniteai_2025&utm_source=partner&utm_medium=referral&utm_campaign=uniteai'}
# {'Title': 'Agentic AI Transformation Summit', 'Dates': 'January 26 to 28, 2026', 'Location': 'Miami, FL', 'Link': 'https://www.processexcellencenetwork.com/events-business-transformation-world-summit/agentic-ai-summit/?utm_source=Event%20Listings&utm_medium=Media%20Partner&utm_campaign=11126.019_MP_UniteAI_EventListing&utm_term=&utm_content=&disc=&extTreatId=7623764'}
# {'Title': '4th Data Science & AI Summit', 'Dates': 'February 9 to 10, 2026', 'Location': 'Dubai, UAE', 'Link': 'https://datascience.thepeopleevents.com/'}
# {'Title': '2nd International Conference on Artificial Intelligence & Data Science', 'Dates': 'February 12 to 13, 2026', 'Location': 'Dubai, UAE', 'Link': 'https://datascience.averconferences.com/'}
# {'Title': '3rd Annual AI in Energy Summit', 'Dates': 'February 23 to 25, 2026', 'Location': 'Houston, TX', 'Link': 'https://www.oilandgasiq.com/events-ai-in-energy?utm_source=Unite%20AI&utm_medium=Media%20Partner&utm_campaign=48819.003-AIE-EXT-Unite-AI&utm_term=&utm_content=&disc=&extTreatId=7623572<br />\n'}
# {'Title': 'AI Automation Conference', 'Dates': 'February 25, 2026', 'Location': 'London, UK', 'Link': 'https://aiautomationconference.com/'}
# {'Title': 'Apres-Cyber Slopes Summit', 'Dates': 'February 25 to 27, 2026', 'Location': 'Park City, UT', 'Link': 'https://www.aprescyber.com/'}
# {'Title': 'European Chatbot & Conversational AI Summit 2026', 'Dates': 'March 17 to 19, 2026', 'Location': 'Edinburgh, Scotland', 'Link': 'https://theeuropeanchatbot.com/'}
# {'Title': 'Big data and Data science Conference 2026', 'Dates': 'April 13 to 14, 2026', 'Location': 'Orlando, FL', 'Link': 'https://datascience-machinelearning.averconferences.com/'}
# {'Title': 'MLcon San Diego', 'Dates': 'June 1 to 5, 2026', 'Location': 'San Diego, CA', 'Link': 'https://mlconference.ai/san-diego/'}
# {'Title': '4th Data Science & AI Summit', 'Dates': 'June 16 to 17, 2025', 'Location': 'London, UK', 'Link': 'https://datascience.thepeopleevents.com/'}
# {'Title': '2nd International Conference on Artificial Intelligence and Machine Learning', 'Dates': 'July 6 to 7, 2026', 'Location': 'Singapore, SG', 'Link': 'https://artificialintelligence.novelticsconferences.com/'}

# %%
ai_events = pd.DataFrame( conferences)

# %%
ai_events.head()
# Out:
#                                                Title  \
# 0                                     GAI World 2025
# 1  7th Annual Machine Learning in Quantitative Fi...
# 2  2nd Edition AI and ML Model Development, Risk ...
# 3  3rd Annual Development, Implementation and Man...
# 4                                     MLcon New York
#
#                              Dates      Location  \
# 0         September 29 to 30, 2025    Boston, MA
# 1  September 29 to October 1, 2025  New York, NY
# 2  September 29 to October 1, 2025  New York, NY
# 3  September 29 to October 1, 2025  New York, NY
# 4  September 30 to October 1, 2025  New York, NY
#
#                                                 Link
# 0                          https://www.gaiworld.com/
# 1                             https://bit.ly/4mzG8SL
# 2  https://www.marcusevans.com/conferences/aifina...
# 3                             https://bit.ly/3SmSfVt
# 4                  https://mlconference.ai/new-york/
