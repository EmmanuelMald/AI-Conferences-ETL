# %% [markdown]
# # AI-Events Extractor
#
# This notebook tests the code to extract AI-related events using web-scrapping from different sources, the first one to test is: [Unite.AI](https://www.unite.ai/conferences/)

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
from loguru import logger
import re
from datetime import datetime
import sys

sys.path.append("../.")

from data_ingestion_pipeline.config import DataSources

# %%
data_sources = DataSources()

# %%
# Step 1: Fetch the page
url = data_sources.TOP_AI_CONFERENCES
headers = {"User-Agent": "Mozilla/5.0"} # To avoid get uncomplete data of the website

logger.info("Sending request to fetch web data")
response = requests.get(url, headers=headers)

if response.status_code != 200:
    raise ValueError(f"The request to {url} failed. Status code: {response.status_code}, {response.text}")

logger.info("Extracting AI events...")
soup = BeautifulSoup(response.content, "html.parser")


# Paso 2: Buscar el tbody directamente
tbody = soup.find("tbody", class_="row-striping")
rows = tbody.find_all("tr")

# Paso 3: Extraer los datos
conferences = []
for row in rows:
    cols = row.find_all("td")
    if len(cols) >= 3:
        dates = cols[0].get_text(strip=True)
        title_tag = cols[1].find("a")
        title = title_tag.get_text(strip=True) if title_tag else cols[1].get_text(strip=True)
        link = title_tag["href"] if title_tag and "href" in title_tag.attrs else None
        location = cols[2].get_text(strip=True)

        conferences.append({
            "Title": title,
            "Dates": dates,
            "Location": location,
            "Link": link
        })

if conferences:
    logger.info("Retrieval succeeded")
else:
    logger.info("Retrieval failed. No data was fetched")
# Out:
# 2025-09-29 12:44:48.889 | INFO     | __main__:<module>:5 - Sending request to fetch web data
# 2025-09-29 12:44:49.660 | INFO     | __main__:<module>:11 - Extracting AI events...
# 2025-09-29 12:44:49.691 | INFO     | __main__:<module>:38 - Retrieval succeeded

# %%
ai_events = pd.DataFrame(conferences)

# %%
ai_events.tail()
# Out:
#                                                 Title                 Dates  \
# 50   European Chatbot & Conversational AI Summit 2026  March 17 to 19, 2026
# 51          Big data and Data science Conference 2026  April 13 to 14, 2026
# 52                                    MLcon San Diego     June 1 to 5, 2026
# 53                       4th Data Science & AI Summit   June 16 to 17, 2025
# 54  2nd International Conference on Artificial Int...     July 6 to 7, 2026
#
#                Location                                               Link
# 50  Edinburgh, Scotland                    https://theeuropeanchatbot.com/
# 51          Orlando, FL  https://datascience-machinelearning.averconfer...
# 52        San Diego, CA                 https://mlconference.ai/san-diego/
# 53           London, UK           https://datascience.thepeopleevents.com/
# 54        Singapore, SG  https://artificialintelligence.novelticsconfer...

# %%
def format_string_date(date_str: str) -> str:
    """
    Formats different types of date strings to the most common format 'YYYY-mm-dd'

    Args:
        date_str: str -> Date string with the format 'October 23, 2025', or 'Oct 23, 2025' 
    
    Returns:
        str -> Date string in the format: '2025-10-23'
    """
    if not isinstance(date_str, str):
        raise ValueError("The date is not a string data type")
    
    for fmt in (r"%B %d, %Y", r"%b %d, %Y"):
        try:
            return datetime.strptime(date_str, fmt).strftime(r"%Y-%m-%d")
        except ValueError:
            continue

    raise ValueError(f"Unrecognized date format: '{date_str}'")
        




def get_initial_and_final_dates(raw_date: str) -> tuple[str]:
    """
    Extracts the initial and final event's date from formats such as: 
            - 'October 23 to 27, 2025'
            - 'Oct 23 to 27, 2025'
            - 'October 23 to November 1, 2025'
    
    In case there's a single-day event, it needs to have the format 'October 23, 2025' or 'Oct 23, 2025'
    
    Args:
        raw_date: str -> Date with the formats provided early
    
    Returns:
        tuple[str] -> Tuple of strings initial and final dates in the format '%Y-%m-%d'
    """
    year_match = re.search(r"\b\d{4}\b", raw_date)
    year = year_match.group(0) if year_match else ""

    if " to " in raw_date:
        dates = raw_date.split(" to ") # spaces are necessary due to "October"

    elif "-" in raw_date: # In case it does not have "to" as a date separator
        dates = raw_date.split("-") # In case there's dates like "Oct 12-20, 2024"

    elif re.search(r"[A-Za-z]+ \d+, \d{4}",raw_date): # In case there's only a single-day event
        initial_date = format_string_date(raw_date)
        final_date = initial_date
        return initial_date, final_date

    else:
        raise ValueError(f"Unknown date format: {raw_date}")

    initial_date = f"{dates[0].strip()}, {year}"

    date_pattern = r"[A-Za-z]+\s\d+, \d{4}" #Looks for 'March 12, 2025' formats

    # If no month is defined in the final_date, the month of the initial_date is set
    final_date = dates[1].strip() if re.search(date_pattern, dates[1].strip()) else f"{initial_date.split()[0]} {dates[1].strip()}"

    # Format string dates
    
    initial_date = format_string_date(initial_date) # In case the month is fully written ("October", "September")
    final_date = format_string_date(final_date)

    return initial_date, final_date

# %%
date_example = "Oct 17 to Nov 20, 2026"

dates = get_initial_and_final_dates(date_example)
print(f"{dates[0]=}, {dates[1]=}")
type(dates)
# Out:
# dates[0]='2026-10-17', dates[1]='2026-11-20'
# tuple

# %%
ai_events[["initial_date","final_date"]] = ai_events["Dates"].apply(get_initial_and_final_dates).apply(pd.Series)

# %%
ai_events.drop("Dates", axis = 1)
# Out:
#                                                 Title             Location  \
# 0                                      GAI World 2025           Boston, MA
# 1   7th Annual Machine Learning in Quantitative Fi...         New York, NY
# 2   2nd Edition AI and ML Model Development, Risk ...         New York, NY
# 3   3rd Annual Development, Implementation and Man...         New York, NY
# 4                                      MLcon New York         New York, NY
# 5                     SDV & AI in Automotive USA 2025        Ann Arbor, Mi
# 6                                 AI in Health summit           London, UK
# 7         1682: The Business of Innovation Conference     Philadelphia, PA
# 8                                     World Summit AI        Amsterdam, NL
# 9                                           CDAO Fall           Boston, MA
# 10                                        DSC DACH 25      Vienna, Austria
# 11                      Banking Transformation Summit        Singapore, SG
# 12  North American Intelligent Cockpit and Smart D...          Detroit, MI
# 13                              AI for the rest of us           London, UK
# 14         Gen AI & HyperAutomation in Finance Summit          Chicago, IL
# 15         dAGI Summit 2025, SF (Open Source AI Week)    San Francisco, CA
# 16                                 Agentic AI Summit,        Amsterdam, NL
# 17                                  ODSC AI West 2025    San Francisco, CA
# 18                           The AI Revolution Summit  Manila, Phillipines
# 19                                     AI Expo Europe   Bucharest, Romania
# 20  Post‑Industrial Summit 2025: Autonomous Organi...       Menlo Park, CA
# 21                                       Future of AI           London, UK
# 22     Conversational AI & Customer Experience Summit      Munich, Germany
# 23  9th Edition Model Risk Management for Financia...           London, UK
# 24                                    AI INFRA SUMMIT    San Francisco, CA
# 25                       AI Summit Seoul & Expo (AIS)         Seoul, Korea
# 26                               AI Regulation Summit           London, UK
# 27                                 Generative AI Week           Austin, TX
# 28                                   AI Policy summit           London, UK
# 29                                  CDAO Fed Ready Q4      Washington D.C.
# 30  Artificial Intelligence and Machine Learning C...        Singapore, SG
# 31                            AI for Marketers Summit              Digital
# 32                      Banking Transformation Summit        Charlotte, NC
# 33                                      DSC Europe 25     Belgrade, Serbia
# 34  EBINTEC Banking Innovation Conference and Exhi...           Dubai, UAE
# 35                            AI in Healthcare Summit           Boston, MA
# 36                 Generative AI for Marketing Summit           London, UK
# 37                                       MLcon Berlin      Berlin, Germany
# 38                       AI World Forum Congress 2025           London, UK
# 39                             Defence Transformation           London, UK
# 40  27th Edition Model Risk Management for Financi...         New York, NY
# 41  3rd Annual AGENTIC AI 2025 | Generative AI Europe     Barcelona, Spain
# 42                                    World Summit AI          Doha, Qatar
# 43                            AI Summit New York 2025         New York, NY
# 44                   Agentic AI Transformation Summit            Miami, FL
# 45                       4th Data Science & AI Summit           Dubai, UAE
# 46  2nd International Conference on Artificial Int...           Dubai, UAE
# 47                     3rd Annual AI in Energy Summit          Houston, TX
# 48                           AI Automation Conference           London, UK
# 49                          Apres-Cyber Slopes Summit        Park City, UT
# 50   European Chatbot & Conversational AI Summit 2026  Edinburgh, Scotland
# 51          Big data and Data science Conference 2026          Orlando, FL
# 52                                    MLcon San Diego        San Diego, CA
# 53                       4th Data Science & AI Summit           London, UK
# 54  2nd International Conference on Artificial Int...        Singapore, SG
#
#                                                  Link initial_date  final_date
# 0                           https://www.gaiworld.com/   2025-09-29  2025-09-30
# 1                              https://bit.ly/4mzG8SL   2025-09-29  2025-10-01
# 2   https://www.marcusevans.com/conferences/aifina...   2025-09-29  2025-10-01
# 3                              https://bit.ly/3SmSfVt   2025-09-29  2025-10-01
# 4                   https://mlconference.ai/new-york/   2025-09-30  2025-10-01
# 5   https://www.automotive-iq.com/events-software-...   2025-09-30  2025-10-02
# 6                             http://econimpact.co/UF   2025-10-01  2025-10-01
# 7                     https://www.1682conference.com/   2025-10-08  2025-10-08
# 8                             https://worldsummit.ai/   2025-10-08  2025-10-09
# 9         https://cdao-fall.coriniumintelligence.com/   2025-10-14  2025-10-15
# 10                               https://dscdach.com/   2025-10-14  2025-10-16
# 11      https://asia.bankingtransformationsummit.com/   2025-10-15  2025-10-15
# 12             https://www.ecv-events.com/NAICSDS2025   2025-10-15  2025-10-16
# 13          https://aifortherestofus.live/london-2025   2025-10-15  2025-10-16
# 14                         https://kinfos.events/haf/   2025-10-16  2025-10-16
# 15  https://dagihouse.com/?utm_source=media_unitea...   2025-10-24  2025-10-24
# 16  https://www.aidataanalytics.network/events-age...   2025-10-27  2025-10-28
# 17                                   https://odsc.ai/   2025-10-28  2025-10-30
# 18         https://air.traiconevents.com/philippines/   2025-10-30  2025-10-30
# 19                      https://www.aiexpoeurope.com/   2025-11-02  2025-11-03
# 20     https://post-industrial.institute/summit-2025/   2025-11-05  2025-11-06
# 21  https://ai.live.ft.com/?promo=UNITEAI&utm_sour...   2025-11-05  2025-11-06
# 22              https://conversationaltechsummit.com/   2025-11-05  2025-11-06
# 23  https://www.marcusevans.com/conferences/modelr...   2025-11-05  2025-11-07
# 24            https://lu.ma/aiinfra_4?coupon=AT2LIM35   2025-11-07  2025-11-07
# 25          https://www.aisummitseoul.com/program2025   2025-11-10  2025-11-11
# 26  https://www.cityandfinancialglobal.com/the-3rd...   2025-11-11  2025-11-11
# 27  https://www.aidataanalytics.network/events-gen...   2025-11-11  2025-11-12
# 28  https://www.cityandfinancialglobal.com/the-uk-...   2025-11-12  2025-11-12
# 29   https://cdao-federal.coriniumintelligence.com/q4   2025-11-12  2025-11-12
# 30  https://pubscholars.org/ai-and-machine-learnin...   2025-11-13  2025-11-14
# 31                             https://bit.ly/3DUK2UT   2025-11-13  2025-11-14
# 32        https://na.bankingtransformationsummit.com/   2025-11-17  2025-11-18
# 33                     https://datasciconference.com/   2025-11-17  2025-11-21
# 34                            https://www.ebintec.com   2025-11-18  2025-11-18
# 35           https://boston-ai-healthcare.re-work.co/   2025-11-18  2025-11-19
# 36  https://www.aidataanalytics.network/events-gen...   2025-11-24  2025-11-26
# 37                    https://mlconference.ai/berlin/   2025-11-24  2025-11-28
# 38                       https://aiconference.london/   2025-11-26  2025-11-27
# 39  https://www.defenceiq.com/events-defencetransf...   2025-12-03  2025-12-04
# 40  https://www.marcusevans.com/conferences/model-...   2025-12-03  2025-12-05
# 41  https://www.aidataanalytics.network/events-gen...   2025-12-03  2025-12-05
# 42                       https://qatar.worldsummit.ai   2025-12-09  2025-12-10
# 43  https://newyork.theaisummit.com/?_mc=cl_aisny_...   2025-12-10  2025-12-11
# 44  https://www.processexcellencenetwork.com/event...   2026-01-26  2026-01-28
# 45           https://datascience.thepeopleevents.com/   2026-02-09  2026-02-10
# 46           https://datascience.averconferences.com/   2026-02-12  2026-02-13
# 47  https://www.oilandgasiq.com/events-ai-in-energ...   2026-02-23  2026-02-25
# 48                https://aiautomationconference.com/   2026-02-25  2026-02-25
# 49                        https://www.aprescyber.com/   2026-02-25  2026-02-27
# 50                    https://theeuropeanchatbot.com/   2026-03-17  2026-03-19
# 51  https://datascience-machinelearning.averconfer...   2026-04-13  2026-04-14
# 52                 https://mlconference.ai/san-diego/   2026-06-01  2026-06-05
# 53           https://datascience.thepeopleevents.com/   2025-06-16  2025-06-17
# 54  https://artificialintelligence.novelticsconfer...   2026-07-06  2026-07-07

# %% [markdown]
# The following code is to generate an excel file that contains a table, which is required by PowerAutomate to correctly identify the table

# %%
from openpyxl.worksheet.table import Table, TableStyleInfo
from openpyxl.utils import get_column_letter

with pd.ExcelWriter('../data/ai_events2.xlsx', engine='openpyxl') as writer:
    ai_events.to_excel(writer, index=False, sheet_name='AI Events')
    workbook  = writer.book
    worksheet = writer.sheets["AI Events"]
    (max_row, max_col) = ai_events.shape

    # Calcula el rango de la tabla en formato Excel (por ejemplo, "A1:D10")
    table_ref = f"A1:{get_column_letter(max_col)}{max_row + 1}"

    table = Table(displayName="AIEventsTable", ref=table_ref)
    style = TableStyleInfo(name="TableStyleMedium9", showFirstColumn=False,
                           showLastColumn=False, showRowStripes=True, showColumnStripes=False)
    table.tableStyleInfo = style
    worksheet.add_table(table)
